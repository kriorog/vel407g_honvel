# %% [markdown]
# ---
# title: "Skilaverkefni 1"
# subtitle: "VÉL407G Hönnun vélbúnaðar - vor 2026"
# author: "Kristján Rögnvaldsson (kristjanor@hi.is)"
#
# format:
#   hi-template-pdf:
#     pdf-engine: xelatex
#     latex-max-runs: 3
#     header-includes:
#       - \newcommand{\leftfootertext}{VÉL407G vor 2026}
#       - \newcommand{\rightfootertext}{Skilaverkefni 1}
#       # - \graphicspath{{fig/}}
#     include-before-body:
#       text: |
#         \vspace{-20mm}
#         \begin{center}
#           Tillaga að lausn.
#         \end{center}
#     titlepage: false
# execute:
#     echo: true
#     output: true
# ---

# %% [markdown]
# <!-- dæmi 1 -->
# {{< embed 01_daemi_1/daemi_1.ipynb >}}
#
# \newpage
#
# <!-- dæmi 2 -->
# {{< embed 02_daemi_2/daemi_2.ipynb >}}
#
# \newpage
#
# <!-- dæmi 3 -->
# {{< embed 03_daemi_3/daemi_3.ipynb >}}
#
# \newpage
#
# <!-- dæmi 4 -->
# {{< embed 04_daemi_4/daemi_4.ipynb >}}
