# %% [markdown]
# ---
# title: "Skilaverkefni 1"
# author: "VÉL407G vor 2026"
# format:
#   pdf:
#     include-in-header: hi_template.tex
#     titlepage: false
# ---

# %% [markdown]
# # Dæmi 1
#
# \newpage

# %% [markdown]
# # Dæmi 2
